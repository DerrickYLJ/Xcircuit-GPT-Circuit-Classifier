# %% [markdown]
# <a href="https://colab.research.google.com/github/DerrickYLJ/10417_final_project/blob/Ethan-Comb/ML_Research_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# !pip install roboflow
# !pip install fastapi
# !pip install kaleido
# !pip install multipart
# !pip install uvicorn

import fastapi
import kaleido
import multipart
import uvicorn
import torch
import torch.nn as nn




from roboflow import Roboflow
from ultralytics import YOLO

# model = YOLO("yolov8n.pt")  # load a pretrained YOLOv8n model
model = YOLO('yolov8n.pt')


rf = Roboflow(api_key="K8P63ZUicTlZO6rZzkQm")
project = rf.workspace("ethan-muchnik-minqm").project("wires-3ev6e")
dataset = project.version(1).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.203, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to Wires-1 in yolov8:: 100%|██████████| 276/276 [00:00<00:00, 5267.81it/s]

# %%
model.train(data='/content/Wires-1/data.yaml', epochs=100, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !bash
# Out:
# bash: cannot set terminal process group (233): Inappropriate ioctl for device
# bash: no job control in this shell
#
#
#
# /content# ^C

# %%
from google.colab import drive
drive.mount('/content/drive')
